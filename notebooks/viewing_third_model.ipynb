# %% [markdown]
# MODEL 3:
#
# What it does?
#
# Lists each film, how many cinemas are playing it, and how much revenue per film in millions they make.
#
# Business Question:
#
# How widely was each film distributed, and how much revenue did it generate?
#
# Takeaway:
#
# Reveals the top films by revenue and their distribution breadth — key for making informed decisions on film distribution and marketing strategies.

# %%
import duckdb

# %%
conn = duckdb.connect(r'..\cinema_tickets.duckdb')
conn

# %% [markdown]
# MODEL 3 QUERY:

# %%
query = """
SELECT 
    film_code, 
    COUNT(DISTINCT cinema_code) AS cinemas_playing_movie,
    ROUND(SUM(total_revenue_usd/1000000), 2) AS revenue_per_film_millions
FROM master_model
GROUP BY film_code
ORDER BY revenue_per_film_millions DESC
"""

conn.execute(query).fetchdf()
# Out:
#     film_code  cinemas_playing_movie  revenue_per_film_millions
# 0        1554                    212                     186.37
# 1        1483                    172                      78.46
# 2        1484                    180                      75.47
# 3        1493                    201                      72.08
# 4        1482                    179                      65.26
# 5        1576                    144                      47.53
# 6        1485                    161                      45.44
# 7        1481                    173                      39.53
# 8        1556                    197                      27.74
# 9        1573                    135                      27.43
# 10       1494                    156                      22.80
# 11       1499                    158                      15.94
# 12       1495                    113                      15.33
# 13       1497                    140                      15.29
# ...

# %% [markdown]
# After creating the table in the duckdb here im just verifying if it runs:

# %%
third_model = """
SELECT *
FROM third_model
"""

# %%
conn.execute(third_model).fetchdf().head()
# Out:
#    film_code  cinemas_playing_movie  revenue_per_film_millions
# 0       1554                    212                     186.37
# 1       1483                    172                      78.46
# 2       1484                    180                      75.47
# 3       1493                    201                      72.08
# 4       1482                    179                      65.26

# %%
conn.close()
